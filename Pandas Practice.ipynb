# %%
import pandas as pd

# %%
countries_df = pd.read_csv('countries.csv')

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %%
countries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   location                    210 non-null    object
#  1   continent                   210 non-null    object
#  2   population                  210 non-null    float64
#  3   life_expectancy             207 non-null    float64
#  4   hospital_beds_per_thousand  164 non-null    float64
#  5   gdp_per_capita              183 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 10.0+ KB

# %%
countries_df.describe()
# Out:
#          population  life_expectancy  hospital_beds_per_thousand  \
# count  2.100000e+02       207.000000                  164.000000
# mean   3.694276e+07        73.529855                    3.012671
# std    1.425092e+08         7.560056                    2.464917
# min    8.090000e+02        53.280000                    0.100000
# 25%    1.031042e+06        69.260000                    1.300000
# 50%    6.909866e+06        75.090000                    2.358500
# 75%    2.615868e+07        78.940000                    3.895750
# max    1.439324e+09        86.750000                   13.800000
#
#        gdp_per_capita
# count      183.000000
# mean     19485.912399
# std      19820.802488
# min        661.240000
# 25%       4504.151000
# 50%      13111.214000
# 75%      28349.983500
# max     116935.600000

# %%
countries_df.shape
# Out:
# (210, 6)

# %%
countries_df.columns
# Out:
# Index(['location', 'continent', 'population', 'life_expectancy',
#        'hospital_beds_per_thousand', 'gdp_per_capita'],
#       dtype='object')

# %%
countries_df.head(9)
# Out:
#               location      continent  population  life_expectancy  \
# 0          Afghanistan           Asia  38928341.0            64.83
# 1              Albania         Europe   2877800.0            78.57
# 2              Algeria         Africa  43851043.0            76.88
# 3              Andorra         Europe     77265.0            83.73
# 4               Angola         Africa  32866268.0            61.15
# 5             Anguilla  North America     15002.0            81.88
# 6  Antigua and Barbuda  North America     97928.0            77.02
# 7            Argentina  South America  45195777.0            76.67
# 8              Armenia           Asia   2963234.0            75.09
#
#    hospital_beds_per_thousand  gdp_per_capita
# 0                        0.50        1803.987
# 1                        2.89       11803.431
# 2                        1.90       13913.839
# 3                         NaN             NaN
# 4                         NaN        5819.495
# ...

# %%
countries_df.tail(9)
# Out:
#            location      continent  population  life_expectancy  \
# 201         Uruguay  South America   3473727.0            77.91
# 202      Uzbekistan           Asia  33469199.0            71.72
# 203         Vatican         Europe       809.0            75.12
# 204       Venezuela  South America  28435943.0            72.06
# 205         Vietnam           Asia  97338583.0            75.40
# 206  Western Sahara         Africa    597330.0            70.26
# 207           Yemen           Asia  29825968.0            66.12
# 208          Zambia         Africa  18383956.0            63.89
# 209        Zimbabwe         Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 201                         2.8       20551.409
# 202                         4.0        6253.104
# 203                         NaN             NaN
# 204                         0.8       16745.022
# 205                         2.6        6171.884
# ...

# %%
countries_df.sample(10)
# Out:
#          location      continent  population  life_expectancy  \
# 44          Congo         Africa   5518092.0            64.57
# 23        Bolivia  South America  11673029.0            71.51
# 5        Anguilla  North America     15002.0            81.88
# 120      Maldives           Asia    540542.0            78.92
# 147        Panama  North America   4314768.0            78.51
# 130    Montserrat  North America      4999.0            74.16
# 190          Togo         Africa   8278737.0            61.04
# 183   Switzerland         Europe   8654618.0            83.78
# 164  Saudi Arabia           Asia  34813867.0            75.13
# 138   New Zealand        Oceania   4822233.0            82.29
#
#      hospital_beds_per_thousand  gdp_per_capita
# 44                          NaN        4881.406
# 23                         1.10        6885.829
# 5                           NaN             NaN
# 120                         NaN       15183.616
# ...

# %% [markdown]
#  How many countries does the dataframe contain?

# %%
num_countries = countries_df.location.shape

# %%
result = int(''.join(map(str, num_countries)))
result
# Out:
# 210

# %%
print('The are {} countries in the datasets.'.format(result))
# Out:
# The are 210 countries in the datasets.

# %%
#continents = countries_df.continent.unique() countries_df.population.sum()

# %% [markdown]
# Retrieve a list of continents from the dataframe?

# %%
continents = countries_df.continent.unique()
continents
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %% [markdown]
#  What is the total population of all the countries listed in this dataset?

# %%
total_population = countries_df.population.sum()
total_population
# Out:
# 7757980095.0

# %%
print('The totla Population is {}.'.format(total_population))
# Out:
# The totla Population is 7757980095.0.

# %% [markdown]
#  What is the overall life expectancy across in the world?

# %%
dforlifeexp = countries_df[['population' , 'life_expectancy']]
dforlifeexp
# Out:
#      population  life_expectancy
# 0    38928341.0            64.83
# 1     2877800.0            78.57
# 2    43851043.0            76.88
# 3       77265.0            83.73
# 4    32866268.0            61.15
# ..          ...              ...
# 205  97338583.0            75.40
# 206    597330.0            70.26
# 207  29825968.0            66.12
# 208  18383956.0            63.89
# 209  14862927.0            61.49
#
# [210 rows x 2 columns]

# %%
countries_df['number_weight_factor'] = countries_df.life_expectancy * countries_df.population

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  number_weight_factor
# 0                          0.50        1803.987          2.523724e+09
# 1                          2.89       11803.431          2.261087e+08
# ...

# %%
world_life_expectancy = countries_df.number_weight_factor.sum() / countries_df.population.sum()
world_life_expectancy
# Out:
# 72.72165193409664

# %%
print('Overall life expectancy across in the wolrd is {:.4}.'.format(world_life_expectancy))
# Out:
# Overall life expectancy across in the wolrd is 72.72.

# %% [markdown]
# Create a dataframe containing 10 countries with the highest population.

# %%
most_populous1_df = countries_df.sort_values(by=['population'], ascending=False)

# %%
most_populous_df = most_populous1_df.head(10).copy()

# %%
most_populous_df
# Out:
#           location      continent    population  life_expectancy  \
# 41           China           Asia  1.439324e+09            76.91
# 90           India           Asia  1.380004e+09            69.66
# 199  United States  North America  3.310026e+08            78.86
# 91       Indonesia           Asia  2.735236e+08            71.72
# 145       Pakistan           Asia  2.208923e+08            67.27
# 27          Brazil  South America  2.125594e+08            75.88
# 141        Nigeria         Africa  2.061396e+08            54.69
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 157         Russia         Europe  1.459345e+08            72.58
# 125         Mexico  North America  1.289328e+08            75.05
#
#      hospital_beds_per_thousand  gdp_per_capita  number_weight_factor
# 41                         4.34       15308.712          1.106984e+11
# 90                         0.53        6426.674          9.613111e+10
# ...

# %% [markdown]
#  Add a new column in countries_df to record the overall GDP per country (product of population & per capita GDP).

# %%
countries_df['gdp'] = countries_df.population* countries_df.gdp_per_capita

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  number_weight_factor  \
# 0                          0.50        1803.987          2.523724e+09
# 1                          2.89       11803.431          2.261087e+08
# ...

# %% [markdown]
# Create a dataframe containing 10 countries with the lowest GDP per capita, among the counties with population greater than 100 million.

# %%
high_population = countries_df[countries_df.population > 100000000 ].copy()

# %%
high_population
# Out:
#           location      continent    population  life_expectancy  \
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 27          Brazil  South America  2.125594e+08            75.88
# 41           China           Asia  1.439324e+09            76.91
# 58           Egypt         Africa  1.023344e+08            71.99
# 63        Ethiopia         Africa  1.149636e+08            66.60
# 90           India           Asia  1.380004e+09            69.66
# 91       Indonesia           Asia  2.735236e+08            71.72
# 99           Japan           Asia  1.264765e+08            84.63
# 125         Mexico  North America  1.289328e+08            75.05
# 141        Nigeria         Africa  2.061396e+08            54.69
# 145       Pakistan           Asia  2.208923e+08            67.27
# 151    Philippines           Asia  1.095811e+08            71.23
# 157         Russia         Europe  1.459345e+08            72.58
# ...

# %%
lowest_GDP = high_population.sort_values(by=['gdp_per_capita'], ascending=True)

# %%
lowest_GDP
# Out:
#           location      continent    population  life_expectancy  \
# 63        Ethiopia         Africa  1.149636e+08            66.60
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 145       Pakistan           Asia  2.208923e+08            67.27
# 141        Nigeria         Africa  2.061396e+08            54.69
# 90           India           Asia  1.380004e+09            69.66
# 151    Philippines           Asia  1.095811e+08            71.23
# 58           Egypt         Africa  1.023344e+08            71.99
# 91       Indonesia           Asia  2.735236e+08            71.72
# 27          Brazil  South America  2.125594e+08            75.88
# 41           China           Asia  1.439324e+09            76.91
# 125         Mexico  North America  1.289328e+08            75.05
# 157         Russia         Europe  1.459345e+08            72.58
# 99           Japan           Asia  1.264765e+08            84.63
# ...

# %%
Ten_lowest_GDP_Countries = lowest_GDP.head(10)
Ten_lowest_GDP_Countries
# Out:
#         location      continent    population  life_expectancy  \
# 63      Ethiopia         Africa  1.149636e+08            66.60
# 15    Bangladesh           Asia  1.646894e+08            72.59
# 145     Pakistan           Asia  2.208923e+08            67.27
# 141      Nigeria         Africa  2.061396e+08            54.69
# 90         India           Asia  1.380004e+09            69.66
# 151  Philippines           Asia  1.095811e+08            71.23
# 58         Egypt         Africa  1.023344e+08            71.99
# 91     Indonesia           Asia  2.735236e+08            71.72
# 27        Brazil  South America  2.125594e+08            75.88
# 41         China           Asia  1.439324e+09            76.91
#
#      hospital_beds_per_thousand  gdp_per_capita  number_weight_factor  \
# 63                         0.30        1729.927          7.656575e+09
# 15                         0.80        3523.984          1.195480e+10
# ...

# %% [markdown]
# Create a data frame that counts the number countries in each continent?

# %%
country_count_df = countries_df.groupby(['continent'])['continent'].count()
country_count_df
# Out:
# continent
# Africa           55
# Asia             47
# Europe           51
# North America    36
# Oceania           8
# South America    13
# Name: continent, dtype: int64

# %%
#2nd- way
country_count_df = countries_df.groupby('continent').count()
country_count_df
# Out:
#                location  population  life_expectancy  \
# continent
# Africa               55          55               55
# Asia                 47          47               47
# Europe               51          51               48
# North America        36          36               36
# Oceania               8           8                8
# South America        13          13               13
#
#                hospital_beds_per_thousand  gdp_per_capita  \
# continent
# Africa                                 40              53
# Asia                                   43              45
# Europe                                 43              42
# North America                          23              27
# Oceania                                 3               4
# South America                          12              12
#
#                number_weight_factor  gdp
# continent
# Africa                           55   53
# Asia                             47   45
# ...

# %% [markdown]
# Create a data frame showing the total population of each continent.

# %%
continent_populations_df = countries_df.groupby(['continent'])['population'].sum()
continent_populations_df
# Out:
# continent
# Africa           1.339424e+09
# Asia             4.607388e+09
# Europe           7.485062e+08
# North America    5.912425e+08
# Oceania          4.095832e+07
# South America    4.304611e+08
# Name: population, dtype: float64

# %%
# Also
continent_population_df = countries_df.groupby('continent').population.sum()
continent_population_df
# Out:
# continent
# Africa           1.339424e+09
# Asia             4.607388e+09
# Europe           7.485062e+08
# North America    5.912425e+08
# Oceania          4.095832e+07
# South America    4.304611e+08
# Name: population, dtype: float64

# %%
covid_data_df = pd.read_csv('covid.csv')

# %%
covid_data_df
# Out:
#            location  total_cases  total_deaths  total_tests
# 0       Afghanistan      38243.0        1409.0          NaN
# 1           Albania       9728.0         296.0          NaN
# 2           Algeria      45158.0        1525.0          NaN
# 3           Andorra       1199.0          53.0          NaN
# 4            Angola       2729.0         109.0          NaN
# ..              ...          ...           ...          ...
# 207  Western Sahara        766.0           1.0          NaN
# 208           World   26059065.0      863535.0          NaN
# 209           Yemen       1976.0         571.0          NaN
# 210          Zambia      12415.0         292.0          NaN
# 211        Zimbabwe       6638.0         206.0      97272.0
#
# [212 rows x 4 columns]

# %% [markdown]
# Count the number of countries for which the total_tests data is missing.

# %%
total_test_missing = covid_data_df.total_tests.isna().sum()
total_test_missing
# Out:
# 122

# %%
print('The data for total tests is missing fro {} countries.'.format(total_test_missing))
# Out:
# The data for total tests is missing fro 122 countries.

# %% [markdown]
# Merge countries_df with covid_data_df on the location column.

# %%
combined_df = pd.merge(countries_df, covid_data_df, on='location')

# %%
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  number_weight_factor  \
# 0                          0.50        1803.987          2.523724e+09
# 1                          2.89       11803.431          2.261087e+08
# ...

# %% [markdown]
# Add columns tests_per_million, cases_per_million and deaths_per_million into combined_df.

# %%
combined_df['tests_per_million'] = combined_df['total_tests'] * 1e6 / combined_df['population'] 
combined_df['cases_per_million'] =  combined_df['total_cases'] * 1e6 / combined_df['population']
combined_df['deaths_per_million'] =  combined_df['total_deaths'] * 1e6 / combined_df['population']

# %%
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  number_weight_factor  \
# 0                          0.50        1803.987          2.523724e+09
# 1                          2.89       11803.431          2.261087e+08
# ...

# %% [markdown]
# Create a dataframe with 10 countires that have highest number of tests per million people.

# %%
highest_tests_df = combined_df.sort_values(by=['tests_per_million'], ascending=False).head(10)

# %%
highest_tests_df
# Out:
#                  location      continent   population  life_expectancy  \
# 197  United Arab Emirates           Asia    9890400.0            77.97
# 14                Bahrain           Asia    1701583.0            77.29
# 115            Luxembourg         Europe     625976.0            82.25
# 122                 Malta         Europe     441539.0            82.53
# 53                Denmark         Europe    5792203.0            80.90
# 96                 Israel           Asia    8655541.0            82.97
# 89                Iceland         Europe     341250.0            82.99
# 157                Russia         Europe  145934460.0            72.58
# 199         United States  North America  331002647.0            78.86
# 10              Australia        Oceania   25499881.0            83.44
#
#      hospital_beds_per_thousand  gdp_per_capita  number_weight_factor  \
# 197                       1.200       67293.483          7.711545e+08
# ...

# %% [markdown]
# Create a dataframe with 10 countires that have highest number of positive cases per million people

# %%
highest_cases_df = combined_df.sort_values(by=['cases_per_million'], ascending=False).head(10)

# %%
highest_cases_df
# Out:
#           location      continent   population  life_expectancy  \
# 155          Qatar           Asia    2881060.0            80.23
# 14         Bahrain           Asia    1701583.0            77.29
# 147         Panama  North America    4314768.0            78.51
# 40           Chile  South America   19116209.0            80.18
# 162     San Marino         Europe      33938.0            84.97
# 9            Aruba  North America     106766.0            76.29
# 105         Kuwait           Asia    4270563.0            75.49
# 150           Peru  South America   32971846.0            76.74
# 27          Brazil  South America  212559409.0            75.88
# 199  United States  North America  331002647.0            78.86
#
#      hospital_beds_per_thousand  gdp_per_capita  number_weight_factor  \
# 155                        1.20      116935.600          2.311474e+08
# 14                         2.00       43290.705          1.315154e+08
# ...

# %% [markdown]
# Create a dataframe with 10 countires that have highest number of deaths cases per million people?

# %%
highest_deaths_df = combined_df.sort_values(by=['deaths_per_million'], ascending=False).head(10)

# %%
highest_deaths_df
# Out:
#            location      continent   population  life_expectancy  \
# 162      San Marino         Europe      33938.0            84.97
# 150            Peru  South America   32971846.0            76.74
# 18          Belgium         Europe   11589616.0            81.63
# 3           Andorra         Europe      77265.0            83.73
# 177           Spain         Europe   46754783.0            83.56
# 198  United Kingdom         Europe   67886004.0            81.32
# 40            Chile  South America   19116209.0            80.18
# 97            Italy         Europe   60461828.0            83.51
# 27           Brazil  South America  212559409.0            75.88
# 182          Sweden         Europe   10099270.0            82.80
#
#      hospital_beds_per_thousand  gdp_per_capita  number_weight_factor  \
# 162                        3.80       56861.470          2.883712e+06
# 150                        1.60       12236.706          2.530259e+09
# ...

# %% [markdown]
# Count number of countries that feature in both the lists of "highest number of tests per million" and "highest number of cases per million".

# %%
countries_in_both = pd.merge(highest_cases_df, highest_tests_df, on='location')
c = countries_in_both.location.count()

# %%
print('Number of countries which feature in both lists are {}.'.format(c))
# Out:
# Number of countries which feature in both lists are 2.

# %% [markdown]
# Count number of countries that feature in both the lists "20 countries with lowest GDP per capita" and "20 countries with the lowest number of hospital beds per thousand population". Only consider countries with a population higher than 10 million while creating the list.

# %%
higher_population = combined_df[combined_df.population > 10e6 ].copy()
higher_population
# Out:
#         location      continent  population  life_expectancy  \
# 0    Afghanistan           Asia  38928341.0            64.83
# 2        Algeria         Africa  43851043.0            76.88
# 4         Angola         Africa  32866268.0            61.15
# 7      Argentina  South America  45195777.0            76.67
# 10     Australia        Oceania  25499881.0            83.44
# ..           ...            ...         ...              ...
# 204    Venezuela  South America  28435943.0            72.06
# 205      Vietnam           Asia  97338583.0            75.40
# 207        Yemen           Asia  29825968.0            66.12
# 208       Zambia         Africa  18383956.0            63.89
# 209     Zimbabwe         Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  number_weight_factor  \
# 0                          0.50        1803.987          2.523724e+09
# 2                          1.90       13913.839          3.371268e+09
# ...

# %%
countries_with_lowest_GDP_per_capita = higher_population.sort_values(by=['gdp_per_capita'], ascending=True).head(20)
countries_with_lowest_GDP_per_capita
# Out:
#                          location      continent   population  \
# 32                        Burundi         Africa   11890781.0
# 52   Democratic Republic of Congo         Africa   89561404.0
# 140                         Niger         Africa   24206636.0
# 118                        Malawi         Africa   19129955.0
# 132                    Mozambique         Africa   31255435.0
# 117                    Madagascar         Africa   27691019.0
# 207                         Yemen           Asia   29825968.0
# 176                   South Sudan         Africa   11193729.0
# 85                          Haiti  North America   11402533.0
# 195                        Uganda         Africa   45741000.0
# 31                   Burkina Faso         Africa   20903278.0
# 63                       Ethiopia         Africa  114963583.0
# 39                           Chad         Africa   16425859.0
# 0                     Afghanistan           Asia   38928341.0
# ...

# %%
countries_with_lowest_number_of_hospitalbeds = higher_population.sort_values(by=['hospital_beds_per_thousand'], ascending=True).head(20)
countries_with_lowest_number_of_hospitalbeds
# Out:
#          location      continent    population  life_expectancy  \
# 121          Mali         Africa  2.025083e+07            59.31
# 117    Madagascar         Africa  2.769102e+07            67.04
# 140         Niger         Africa  2.420664e+07            62.42
# 135         Nepal           Asia  2.913681e+07            70.78
# 82         Guinea         Africa  1.313279e+07            61.60
# 63       Ethiopia         Africa  1.149636e+08            66.60
# 31   Burkina Faso         Africa  2.090328e+07            61.58
# 195        Uganda         Africa  4.574100e+07            63.37
# 0     Afghanistan           Asia  3.892834e+07            64.83
# 20          Benin         Africa  1.212320e+07            61.77
# 90          India           Asia  1.380004e+09            69.66
# 80      Guatemala  North America  1.791557e+07            74.30
# 145      Pakistan           Asia  2.208923e+08            67.27
# 85          Haiti  North America  1.140253e+07            64.00
# ...

# %%
countries_in_both = pd.merge(countries_with_lowest_GDP_per_capita, countries_with_lowest_number_of_hospitalbeds, on='location').head(20)

# %%
countries_in_both
# Out:
#         location    continent_x  population_x  life_expectancy_x  \
# 0        Burundi         Africa    11890781.0              61.58
# 1          Niger         Africa    24206636.0              62.42
# 2     Mozambique         Africa    31255435.0              60.85
# 3     Madagascar         Africa    27691019.0              67.04
# 4          Yemen           Asia    29825968.0              66.12
# 5          Haiti  North America    11402533.0              64.00
# 6         Uganda         Africa    45741000.0              63.37
# 7   Burkina Faso         Africa    20903278.0              61.58
# 8       Ethiopia         Africa   114963583.0              66.60
# 9    Afghanistan           Asia    38928341.0              64.83
# 10        Guinea         Africa    13132792.0              61.60
# 11          Mali         Africa    20250834.0              59.31
# 12         Benin         Africa    12123198.0              61.77
# ...

# %%
#combine way to do
lowest_gdp_per_capita = combined_df[combined_df.population>10e6].sort_values('gdp_per_capita',ascending=True).head(20)
lowest_hospitals_beds = combined_df[combined_df.population>10e6].sort_values('hospital_beds_per_thousand',ascending=True).head(20)

lowest_gdp_per_capita.merge(lowest_hospitals_beds,on='location')
# Out:
#         location    continent_x  population_x  life_expectancy_x  \
# 0        Burundi         Africa    11890781.0              61.58
# 1          Niger         Africa    24206636.0              62.42
# 2     Mozambique         Africa    31255435.0              60.85
# 3     Madagascar         Africa    27691019.0              67.04
# 4          Yemen           Asia    29825968.0              66.12
# 5          Haiti  North America    11402533.0              64.00
# 6         Uganda         Africa    45741000.0              63.37
# 7   Burkina Faso         Africa    20903278.0              61.58
# 8       Ethiopia         Africa   114963583.0              66.60
# 9    Afghanistan           Asia    38928341.0              64.83
# 10        Guinea         Africa    13132792.0              61.60
# 11          Mali         Africa    20250834.0              59.31
# 12         Benin         Africa    12123198.0              61.77
# ...
