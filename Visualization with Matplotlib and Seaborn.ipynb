# %%
import numpy as np 

import pandas as pd 
import matplotlib.pyplot as plt

import seaborn as sns 
# %matplotlib inline

# %% [markdown]
# ### Line Chart

# %%
yeild_apples = [0.895, 0.91, 0.919, 0.934, 0.938, 0.944, 0.951]

# %%
plt.plot(yeild_apples);

# %% [markdown]
# ### Customizing the X-axis

# %%
years = [2012, 2013, 2014, 2015, 2016, 2017, 2018 ]
yeild_apples = [0.895, 0.91, 0.919, 0.934, 0.938, 0.944, 0.951]

# %%
plt.plot(years, yeild_apples);

# %% [markdown]
# ### Axis Labels

# %%
plt.plot(years, yeild_apples);
plt.xlabel('Number of Years');
plt.ylabel('Yeild Apples');

# %% [markdown]
# ### Plotting Multiple Lines

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

# %%
plt.plot(years, apples);
plt.plot(years, oranges);
plt.xlabel('Number of Years');
plt.ylabel('Yeild Per Year');

# %% [markdown]
# ### Chart Title and Legend

# %%
plt.plot(years, apples);
plt.plot(years, oranges);
plt.xlabel('Number of Years');
plt.ylabel('Yeild Per Year');
plt.title('Crop Yeilds in Punjab');
plt.legend(['Apples','Oranges']);

# %% [markdown]
# ### Line Markers

# %% [markdown]
# https://matplotlib.org/3.1.1/api/markers_api.html .

# %%
plt.plot(years, apples, marker= 'o');
plt.plot(years, oranges, marker= 'x');
plt.xlabel('Number of Years');
plt.ylabel('Yeild Per Year');
plt.title('Crop Yeilds in Punjab');
plt.legend(['Apples','Oranges']);

# %% [markdown]
# Styling Lines and Markers
# The plt.plot function supports many arguments for styling lines and markers:
#
# color or c: Set the color of the line (supported colors)
#
# linestyle or ls: Choose between a solid or dashed line
#
# linewidth or lw: Set the width of a line
#
# markersize or ms: Set the size of markers
#
# markeredgecolor or mec: Set the edge color for markers
#
# markeredgewidth or mew: Set the edge width for markers
#
# markerfacecolor or mfc: Set the fill color for markers
#
# alpha: Opacity of the plot

# %% [raw]
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot .

# %% [markdown]
# ### Changing the Figure Size

# %%
plt.plot(years, apples, marker='s', c='b', ls='-', lw=2, ms=8, mew=2, mec='navy')
plt.plot(years, oranges, marker='o', c='r', ls='--', lw=3, ms=10, alpha=.5)

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %%
# A Short Foam of the above graph 
plt.plot(years, apples, 's-b')
plt.plot(years, oranges, 'o-r')

plt.xlabel('Years')
plt.ylabel('Yield(Tons per Hectare)')

plt.title('Crop Yeild in Punjab')
plt.legend(['Apples' , 'Oranges']);

# %% [markdown]
# ### Changing the Figure Size

# %%
plt.figure(figsize=(12,6))

plt.plot(years, oranges)
plt.title('Yield of Oranges ')
# Out:
# Text(0.5, 1.0, 'Yield of Oranges ')

# %% [markdown]
# ### Improving Default Styles using Seaborn

# %%
sns.set_style('whitegrid')

# %%
plt.plot(years, apples, 's-b')
plt.plot(years, oranges, 'o-r')

plt.xlabel ('Years')
plt.ylabel ('Yield (Tons per Hector)')

plt.title('Crop Yeild in Punjab')
plt.legend(['Apples' , 'Oranges']);

# %%
sns.set_style('darkgrid')

# %%
plt.plot(years, apples, 's-b')
plt.plot(years, oranges, 'o-r')

plt.xlabel ('Years')
plt.ylabel ('Yield (Tons per Hector)')

plt.title('Crop Yeild in Punjab')
plt.legend(['Apples' , 'Oranges']);

# %% [markdown]
# ### Scatter Plot

# %%
flower_df = pd.read_csv('flowerdat.csv', delimiter = '	', header = None)
flower_df.columns = ["Sr.No", "sepal_length", "sepal_width", "petal_length" , "petal_width" , "species"]

# %%
flower_df
# Out:
#      Sr.No  sepal_length  sepal_width  petal_length  petal_width       species
# 0        1           5.1          3.5           1.4          0.2     I. setosa
# 1        2           4.9          3.0           1.4          0.2     I. setosa
# 2        3           4.7          3.2           1.3          0.2     I. setosa
# 3        4           4.6          3.1           1.5          0.2     I. setosa
# 4        5           5.0          3.6           1.4          0.3     I. setosa
# ..     ...           ...          ...           ...          ...           ...
# 145    146           6.7          3.0           5.2          2.3  I. virginica
# 146    147           6.3          2.5           5.0          1.9  I. virginica
# 147    148           6.5          3.0           5.2          2.0  I. virginica
# 148    149           6.2          3.4           5.4          2.3  I. virginica
# 149    150           5.9          3.0           5.1          1.8  I. virginica
#
# [150 rows x 6 columns]

# %%
flower_df.set_index('Sr.No', inplace = True)

# %%
flower_df
# Out:
#        sepal_length  sepal_width  petal_length  petal_width       species
# Sr.No
# 1               5.1          3.5           1.4          0.2     I. setosa
# 2               4.9          3.0           1.4          0.2     I. setosa
# 3               4.7          3.2           1.3          0.2     I. setosa
# 4               4.6          3.1           1.5          0.2     I. setosa
# 5               5.0          3.6           1.4          0.3     I. setosa
# ...             ...          ...           ...          ...           ...
# 146             6.7          3.0           5.2          2.3  I. virginica
# 147             6.3          2.5           5.0          1.9  I. virginica
# 148             6.5          3.0           5.2          2.0  I. virginica
# 149             6.2          3.4           5.4          2.3  I. virginica
# 150             5.9          3.0           5.1          1.8  I. virginica
#
# [150 rows x 5 columns]

# %%
flower_df.loc[2]
# Out:
# sepal_length          4.9
# sepal_width           3.0
# petal_length          1.4
# petal_width           0.2
# species         I. setosa
# Name: 2, dtype: object

# %%
flower_df[['species']]
# Out:
#             species
# Sr.No
# 1         I. setosa
# 2         I. setosa
# 3         I. setosa
# 4         I. setosa
# 5         I. setosa
# ...             ...
# 146    I. virginica
# 147    I. virginica
# 148    I. virginica
# 149    I. virginica
# 150    I. virginica
#
# [150 rows x 1 columns]

# %%
flower_df.species.unique()
# Out:
# array(['I. setosa', 'I. versicolor', 'I. virginica'], dtype=object)

# %%
plt.plot(flower_df.sepal_length, flower_df.sepal_width)

# %%
sns.scatterplot(x= flower_df.sepal_length , y = flower_df.sepal_width);

# %% [markdown]
# ### Adding Hues

# %%
sns.scatterplot(x= flower_df.sepal_length, y= flower_df.sepal_width, hue= flower_df.species, s= 130)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ### Customizing Seaborn Figures

# %%
plt.figure(figsize=(12, 7))
plt.title('Sepal Dimensions')

sns.scatterplot(x=flower_df.sepal_length,
               y= flower_df.sepal_width,
              hue= flower_df.species,
              s= 100);

# %% [markdown]
# ### Plotting using Pandas Data Frames

# %%
plt.title('Sepal Dimensions')
sns.scatterplot(x= 'sepal_length',
                y= 'sepal_width',
                hue = 'species',
                s= 100,
               data= flower_df);

# %% [markdown]
# ### Histogram

# %%
flower_df.sepal_width
# Out:
# Sr.No
# 1      3.5
# 2      3.0
# 3      3.2
# 4      3.1
# 5      3.6
#       ...
# 146    3.0
# 147    2.5
# 148    3.0
# 149    3.4
# 150    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
plt.title('Distribution of Sepal Width')
plt.xlabel ('Sepal Lengths')
plt.ylabel ('Number of Samples')

#plt.hist(flower_df.sepal_length);
plt.hist(flower_df.sepal_width);

# %% [markdown]
# ### Controlling the Size and Number of Bins

# %%
# Number of Bins
plt.hist(flower_df.sepal_width, bins= 2);
plt.hist(flower_df.sepal_width, bins= 5);
plt.hist(flower_df.sepal_width, bins= 8);

# %%
# Boundaries of each bin 
'''np.arange(2,4.8,0.1)); in this firts is starting point, second is end
point and last one is increment''' 
plt.hist(flower_df.sepal_width, bins = np.arange(2,4.8,0.1));

# %%
# Unqual Size of Bins 

#plt.hist(flower_df.sepal_width, bins= [1,4,4.3]);
plt.hist(flower_df.sepal_width, bins= [1,2.3,3,4, 5.3]);

# %% [markdown]
# ### Multiple Histrograms

# %%
setosa_df = flower_df[flower_df.species == 'I. setosa']
versicolor_df = flower_df[flower_df.species == 'I. versicolor']
virginica_df = flower_df[flower_df.species == ' I. virginica']

# %%
plt.hist(setosa_df.sepal_width, alpha=0.4, bins=np.arange(1, 6, 0.25));
plt.hist(versicolor_df.sepal_width, alpha=0.4, bins=np.arange(1, 6, 0.25));

# %%
setosa_df
# Out:
#        sepal_length  sepal_width  petal_length  petal_width    species
# Sr.No
# 1               5.1          3.5           1.4          0.2  I. setosa
# 2               4.9          3.0           1.4          0.2  I. setosa
# 3               4.7          3.2           1.3          0.2  I. setosa
# 4               4.6          3.1           1.5          0.2  I. setosa
# 5               5.0          3.6           1.4          0.3  I. setosa
# 6               5.4          3.9           1.7          0.4  I. setosa
# 7               4.6          3.4           1.4          0.3  I. setosa
# 8               5.0          3.4           1.5          0.2  I. setosa
# 9               4.4          2.9           1.4          0.2  I. setosa
# 10              4.9          3.1           1.5          0.1  I. setosa
# 11              5.4          3.7           1.5          0.2  I. setosa
# 12              4.8          3.4           1.6          0.2  I. setosa
# ...

# %%
# Histrogram on Each Other 
plt.title ('Distribution of Sepal Width')
plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width],
        bins = np.arange(1,5,0.25),
        stacked= True)
plt.legend(['Setosa', 'Versicolor', 'Virginica']);

# %% [markdown]
# ### Bar Chart

# %%
years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
plt.bar(years, oranges);

# %%
plt.bar(years, apples)
plt.bar(years, oranges, bottom=apples);

# %% [markdown]
# ### Bar Plots with Averages

# %%
tips_df = sns.load_dataset("tips");

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_df.loc[77]
# Out:
# total_bill     27.2
# tip             4.0
# sex            Male
# smoker           No
# day            Thur
# time          Lunch
# size              4
# Name: 77, dtype: object

# %%
tips_df_1= tips_df[['total_bill', 'day']]

# %%
tips_df_1
# Out:
#      total_bill   day
# 0         16.99   Sun
# 1         10.34   Sun
# 2         21.01   Sun
# 3         23.68   Sun
# 4         24.59   Sun
# ..          ...   ...
# 239       29.03   Sat
# 240       27.18   Sat
# 241       22.67   Sat
# 242       17.82   Sat
# 243       18.78  Thur
#
# [244 rows x 2 columns]

# %%
tips_df["total_bill"]. mean()
# Out:
# 19.78594262295082

# %%
i = 'Thur'
bills_on_Thur=tips_df.loc[tips_df["day"]==i]["total_bill"]
i = 'Fri'
bills_on_Fri=tips_df.loc[tips_df["day"]==i]["total_bill"]
i = 'Sat'
bills_on_Sat=tips_df.loc[tips_df["day"]==i]["total_bill"]
i = 'Sun'
bills_on_sunday=tips_df.loc[tips_df["day"]==i]["total_bill"]

# %%
bills_on_Thur
# Out:
# 77     27.20
# 78     22.76
# 79     17.29
# 80     19.44
# 81     16.66
#        ...
# 202    13.00
# 203    16.40
# 204    20.53
# 205    16.47
# 243    18.78
# Name: total_bill, Length: 62, dtype: float64

# %%
a = bills_on_Thur.mean()
b = bills_on_Fri.mean()
c = bills_on_Sat.mean()
d = bills_on_sunday.mean()

# %%
print('Average Bill on Thur is {:.2f} , Average Bill on Fri is {:.2f} , Average Bill on Sat is {:.2f} and Average Bill on Sunday is {:.2f} ' .format(a, b, c, d))
# Out:
# Average Bill on Thur is 17.68 , Average Bill on Fri is 17.15 , Average Bill on Sat is 20.44 and Average Bill on Sunday is 21.41

# %%
tips_df.total_bill.mean()
# Out:
# 19.78594262295082

# %%
e = ['Thur', 'Fri', 'Sat', 'Sun']
f = [a, b, c, d]


plt.bar(e,f);

# %%
#Average Bar 
sns.barplot(x= 'day', y = 'total_bill' , data= tips_df);

# %%
sns.barplot(x='day', y= 'total_bill', hue= 'sex' , data= tips_df);

# %%
sns.barplot(x='day', y= 'total_bill', hue= 'smoker' , data= tips_df);

# %%
sns.barplot(x='day', y= 'total_bill', hue= 'time' , data= tips_df);

# %%
sns.barplot(x='total_bill', y='day', hue='sex', data=tips_df);

# %% [markdown]
# ### Heat Maps

# %%
flights_df = sns.load_dataset("flights")

# %%
flights_df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights_df = flights_df.pivot(index='month', columns='year', values='passengers')

# %%
flights_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.title("No. of Passengers (1000s)")

sns.heatmap(flights_df);

# %%
plt.title("No. of Passengers (1000s)")
sns.heatmap(flights_df, fmt="d", annot=True, cmap='Blues');

# %% [markdown]
# ### Images

# %%
from PIL import Image

# %%
image = Image.open('download.png')

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=264x191>

# %%
image_array = np.array(image)

# %%
image_array.shape
# Out:
# (191, 264)

# %%
plt.imshow(image);

# %%
plt.grid(False)
plt.title('School Graph ')
plt.axis('off')
plt.imshow(image);

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(image_array[89:189,109:209]);

# %% [markdown]
# ### Plotting Multiple Charts in a Grid

# %% [markdown]
# A full list of supported functions: https://matplotlib.org/3.3.1/api/axes_api.html#the-axes-class .

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 9))
# Axes for Plotting
axes[0,0].plot(years, apples, 's-b')
axes[0,0].plot(years, oranges, 'o-r')
axes[0,0].set_xlabel('Years')
axes[0,0].set_ylabel('Yield')
axes[0,0].legend(['Apple', 'Oranges']);
axes[0,0].set_title('Crop Yield in Punjab')


# Axes into Seaborn
axes[0,1].set_title('Sepel Length vs. Sepal Width')
sns.scatterplot(x=flower_df.sepal_length,
               y= flower_df.sepal_width,
               hue = flower_df.species,
               s=100,
               ax=axes[0,1]);

# Axes for Plotting 
axes[0,2].set_title ('Distribution of Sepal Width')
axes[0,2].hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width],
        bins = np.arange(2,5,0.25),
        stacked= True);
axes[0,2].legend(['Setosa', 'Versicolor', 'Virginica']);

# Axes into Seaborn
axes[1,0].set_title('Resturant Bills')
sns.barplot(x= 'day' , y = 'total_bill' , hue='sex', data = tips_df, ax= axes[1,0]);

     
# Axes to Seaborn 
axes[1,1].set_title('Flight traffic')
sns.heatmap(flights_df, cmap='Blues', ax=axes[1,1]);
     

     
     
axes[1,2].set_title('School Graph')     
axes[1,2].grid(False)
axes[1,2].imshow(image);    
axes[1,2].set_xticks([])
axes[1,2].set_yticks([])
# Out:
# []

# %% [markdown]
# ### Pair Plots with Seaborn

# %%
sns.pairplot(flower_df, hue='species');
# Out:
# C:\Users\asada\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(tips_df, hue='sex')
# Out:
# C:\Users\asada\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
